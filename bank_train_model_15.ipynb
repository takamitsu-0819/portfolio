# %%
#特徴量全使用+全ダミー化
#day+month循環数化
#+category型job/education/contact/poutcome列のunknown多変量補完
#特徴量16
#スコア：

# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.base import BaseEstimator, TransformerMixin

# %%
#データ読込
df=pd.read_csv("/content/bank_train.csv")

# %%
#dtype確認
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27128 entries, 0 to 27127
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         27128 non-null  int64
#  1   age        27128 non-null  int64
#  2   job        27128 non-null  object
#  3   marital    27128 non-null  object
#  4   education  27128 non-null  object
#  5   default    27128 non-null  object
#  6   balance    27128 non-null  int64
#  7   housing    27128 non-null  object
#  8   loan       27128 non-null  object
#  9   contact    27128 non-null  object
#  10  day        27128 non-null  int64
#  11  month      27128 non-null  object
#  12  duration   27128 non-null  int64
#  13  campaign   27128 non-null  int64
#  14  pdays      27128 non-null  int64
#  15  previous   27128 non-null  int64
#  16  poutcome   27128 non-null  object
#  17  y          27128 non-null  int64
# dtypes: int64(9), object(9)
# memory usage: 3.7+ MB

# %%
#使用col
use_cols = ["id",
    "age",
    'job',
    'marital',
    'education',
    'default',
    "balance",
    "housing",
    "loan",
    "contact",
    "day",
    "month",
    "duration",
    "campaign",
    'pdays',
    'previous',
    "poutcome",
     "y"]
df_use = df[use_cols]
df_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27128 entries, 0 to 27127
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         27128 non-null  int64
#  1   age        27128 non-null  int64
#  2   job        27128 non-null  object
#  3   marital    27128 non-null  object
#  4   education  27128 non-null  object
#  5   default    27128 non-null  object
#  6   balance    27128 non-null  int64
#  7   housing    27128 non-null  object
#  8   loan       27128 non-null  object
#  9   contact    27128 non-null  object
#  10  day        27128 non-null  int64
#  11  month      27128 non-null  object
#  12  duration   27128 non-null  int64
#  13  campaign   27128 non-null  int64
#  14  pdays      27128 non-null  int64
#  15  previous   27128 non-null  int64
#  16  poutcome   27128 non-null  object
#  17  y          27128 non-null  int64
# dtypes: int64(9), object(9)
# memory usage: 3.7+ MB

# %%
def data_pre(df):
    job_dis = {
    "blue-collar": 0,
    "management": 1,
    "technician": 2,
    "admin.": 3,
    "services": 4,
    "retired": 5,
    "self-employed": 6,
    "entrepreneur": 7,
    "unemployed": 8,
    "housemaid": 9,
    "student": 10,
    "unkown": np.nan
    }
    education_dis={
        "primary": 0,
        "secondary": 1,
        "tertiary": 2,
        "unkown": np.nan
    }
    contact_dis={
        "cellular": 0,
        "telephone": 1,
        "unkown": np.nan
    }
    poutcome_dis={
        "failure": 0,
        "other": 1,
        "success": 2,
        "unkown": np.nan
    }

    df["job"] = df["job"].map(job_dis)
    df["education"] = df["education"].map(education_dis)
    df["contact"] = df["contact"].map(contact_dis)
    df["poutcome"] = df["poutcome"].map(poutcome_dis)

    #月+日の循環数化
    dic={"jan":1,"feb":2,"mar":3,"apr":4,"may":5,"jun":6,"jul":7,"aug":8,"sep":9,"oct":10,"nov":11,"dec":12}
    df["month"]=df["month"].map(dic).astype(int)
    df["day"]=df["day"].astype(int)

    total_days_in_year = 365  # 仮定として、1年が365日とする
    month_day_number = (df["month"] - 1) * 31 + df["day"]  # 仮定として、1月から12月まで31日とする
    angle = (2 * np.pi * month_day_number) / total_days_in_year

    df["month_day_sin"] = np.sin(angle)
    df["month_day_cos"] = np.cos(angle)

    df = df.drop(columns=['month'], axis=1)
    df = df.drop(columns=['day'], axis=1)

    #marital列のダミー変数化
    dummies_marital=pd.get_dummies(df["marital"], dtype=int,drop_first=True,prefix="marital")
    df = pd.concat([df, dummies_marital], axis=1)
    df.drop(columns=['marital'], inplace=True)

    #default列のダミー変数化+置換
    dummies_default=pd.get_dummies(df["default"], dtype=int,drop_first=True,prefix="default")
    df = pd.concat([df, dummies_default], axis=1)
    df.drop(columns=['default'], inplace=True)

    #housing列のダミー変数化+置換
    dummies_housing=pd.get_dummies(df["housing"], dtype=int,drop_first=True,prefix="housing")
    df = pd.concat([df, dummies_housing], axis=1)
    df.drop(columns=['housing'], inplace=True)

    #loan列のダミー変数化
    dummies_loan=pd.get_dummies(df["loan"], dtype=int,drop_first=True,prefix="loan")
    df = pd.concat([df, dummies_loan], axis=1)
    df.drop(columns=['loan'], inplace=True)

    #多重代入法のインスタンス化と適用
    imputer = IterativeImputer(random_state=0)
    imputed_data = imputer.fit_transform(df)
    df = pd.DataFrame(imputed_data, columns=df.columns)

    df["job"] = np.round(df["job"]).astype(int)
    df["education"] = np.round(df["education"]).astype(int)
    df["contact"] = np.round(df["contact"]).astype(int)
    df["poutcome"] = np.round(df["poutcome"]).astype(int)

    job_dis_inv = {v: k for k, v in job_dis.items()}
    education_dis_inv = {v: k for k, v in education_dis.items()}
    contact_dis_inv = {v: k for k, v in contact_dis.items()}
    poutcome_dis_inv = {v: k for k, v in poutcome_dis.items()}

    df['job'] = df['job'].map(job_dis_inv)
    df["education"] = df["education"].map(job_dis_inv)
    df["contact"] = df["contact"].map(job_dis_inv)
    df["poutcome"] = df["poutcome"].map(job_dis_inv)

    #job列のダミー変数化
    dummies_job=pd.get_dummies(df["job"], dtype=int,drop_first=True,prefix="job")
    df = pd.concat([df, dummies_job], axis=1)
    df.drop(columns=['job'], inplace=True)

    #education列のダミー変数化
    dummies_education=pd.get_dummies(df["education"], dtype=int,drop_first=True,prefix="education")
    df = pd.concat([df, dummies_education], axis=1)
    df.drop(columns=['education'], inplace=True)

    #contact列のダミー変数化+置換
    dummies_contact=pd.get_dummies(df["contact"], dtype=int,drop_first=True,prefix="contact")
    df = pd.concat([df, dummies_contact], axis=1)
    df.drop(columns=['contact'], inplace=True)

    #poutcome列のダミー変数化+置換
    dummies_poutcome=pd.get_dummies(df["poutcome"], dtype=int,drop_first=True,prefix="poutcome")
    df = pd.concat([df, dummies_poutcome], axis=1)
    df.drop(columns=['poutcome'], inplace=True)

    #IDカテゴリー化
    df["id"]=df["id"].astype("category")

    return df

df_use["y"]=df["y"]
df_use=data_pre(df_use)

# %%
df_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27128 entries, 0 to 27127
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    27128 non-null  category
#  1   age                   27128 non-null  float64
#  2   balance               27128 non-null  float64
#  3   duration              27128 non-null  float64
#  4   campaign              27128 non-null  float64
#  5   pdays                 27128 non-null  float64
#  6   previous              27128 non-null  float64
#  7   y                     27128 non-null  float64
#  8   month_day_sin         27128 non-null  float64
#  9   month_day_cos         27128 non-null  float64
#  10  marital_married       27128 non-null  float64
#  11  marital_single        27128 non-null  float64
#  12  default_yes           27128 non-null  float64
#  13  housing_yes           27128 non-null  float64
#  14  loan_yes              27128 non-null  float64
#  15  job_blue-collar       27128 non-null  int64
#  16  job_entrepreneur      27128 non-null  int64
#  17  job_housemaid         27128 non-null  int64
#  18  job_management        27128 non-null  int64
#  19  job_retired           27128 non-null  int64
#  20  job_self-employed     27128 non-null  int64
#  21  job_services          27128 non-null  int64
#  22  job_student           27128 non-null  int64
#  23  job_technician        27128 non-null  int64
#  24  job_unemployed        27128 non-null  int64
#  25  education_management  27128 non-null  int64
#  26  education_technician  27128 non-null  int64
#  27  contact_management    27128 non-null  int64
#  28  poutcome_management   27128 non-null  int64
#  29  poutcome_technician   27128 non-null  int64
# dtypes: category(1), float64(14), int64(15)
# memory usage: 7.3 MB

# %%
df_use.corr()
# Out:
#                             id       age   balance  duration  campaign  \
# id                    1.000000 -0.005716 -0.000484  0.002705  0.016867
# age                  -0.005716  1.000000  0.095343 -0.005309 -0.001340
# balance              -0.000484  0.095343  1.000000  0.019923 -0.016295
# duration              0.002705 -0.005309  0.019923  1.000000 -0.087771
# campaign              0.016867 -0.001340 -0.016295 -0.087771  1.000000
# pdays                -0.004526 -0.025272  0.003613  0.002030 -0.086220
# previous             -0.005425  0.002946  0.012483  0.002489 -0.031557
# y                    -0.003555  0.020892  0.045826  0.401390 -0.076118
# month_day_sin        -0.001468 -0.121463 -0.060886  0.031699 -0.144354
# month_day_cos        -0.009061  0.039813  0.085569  0.006577 -0.127817
# marital_married      -0.001536  0.287000  0.023216 -0.018632  0.031635
# marital_single        0.004125 -0.426678 -0.010691  0.013641 -0.018753
# default_yes           0.003077 -0.017648 -0.065476 -0.010041  0.014263
# housing_yes           0.002384 -0.188127 -0.069700  0.008042 -0.020902
# loan_yes              0.007667 -0.019236 -0.084834 -0.010103  0.010495
# job_blue-collar       0.004930 -0.045403 -0.054156  0.005908  0.011072
# job_entrepreneur      0.002452  0.017521  0.019705  0.003934  0.001953
# job_housemaid        -0.007486  0.084770  0.004116 -0.010372 -0.000506
# job_management        0.001762 -0.022864  0.073787 -0.009806  0.018882
# job_retired           0.002032  0.447656  0.044341  0.024644 -0.036441
# job_self-employed     0.002136 -0.010758  0.017235  0.011423  0.003895
# job_services         -0.003425 -0.063167 -0.037707 -0.000211 -0.004259
# job_student           0.006958 -0.195871  0.001307 -0.009369 -0.021345
# job_technician       -0.000349 -0.065888 -0.019928 -0.006641  0.027572
# job_unemployed        0.000994  0.001172  0.009060  0.021198 -0.019626
# education_management -0.000704 -0.056198 -0.075578 -0.000293 -0.017564
# education_technician  0.001802 -0.087869  0.097979  0.003627  0.011621
# contact_management    0.002645  0.172744  0.029963 -0.017818  0.055935
# poutcome_management   0.003582 -0.013460 -0.036253 -0.046870  0.068714
# poutcome_technician   0.010168  0.034344  0.031568  0.070765  0.042658
#
#                          pdays  previous         y  month_day_sin  \
# id                   -0.004526 -0.005425 -0.003555      -0.001468
# age                  -0.025272  0.002946  0.020892      -0.121463
# balance               0.003613  0.012483  0.045826      -0.060886
# duration              0.002030  0.002489  0.401390       0.031699
# campaign             -0.086220 -0.031557 -0.076118      -0.144354
# pdays                 1.000000  0.421606  0.100930       0.166833
# previous              0.421606  1.000000  0.083825       0.045888
# y                     0.100930  0.083825  1.000000      -0.030973
# month_day_sin         0.166833  0.045888 -0.030973       1.000000
# month_day_cos         0.156656  0.131636  0.086606      -0.079836
# marital_married      -0.025074 -0.009969 -0.059377      -0.061070
# marital_single        0.025228  0.013445  0.062806       0.060644
# default_yes          -0.031555 -0.016082 -0.017005      -0.013894
# housing_yes           0.128671  0.035886 -0.140307       0.374450
# loan_yes             -0.019021 -0.008316 -0.065630      -0.029495
# job_blue-collar       0.018139 -0.020051 -0.071971       0.161773
# job_entrepreneur     -0.014195 -0.006844 -0.017122      -0.007798
# job_housemaid        -0.028079 -0.010539 -0.014899      -0.049118
# job_management       -0.013875  0.013184  0.030974      -0.113423
# job_retired          -0.012303  0.005046  0.077087      -0.057360
# job_self-employed    -0.014384 -0.002959  0.004024      -0.024142
# job_services          0.007112 -0.011628 -0.024128       0.055700
# job_student           0.025159  0.019321  0.081543       0.006988
# job_technician       -0.007087  0.007965 -0.015128      -0.083477
# job_unemployed       -0.006487 -0.005428  0.025624       0.010224
# education_management  0.019596 -0.007584 -0.027451       0.095131
# education_technician -0.010087  0.022724  0.063568      -0.138438
# contact_management    0.015162  0.018798  0.015431      -0.061249
# poutcome_management  -0.657569 -0.336882 -0.204506      -0.054899
# poutcome_technician   0.173681  0.149258  0.385849      -0.067777
#
#                       month_day_cos  ...  job_self-employed  job_services  \
# id                        -0.009061  ...           0.002136     -0.003425
# age                        0.039813  ...          -0.010758     -0.063167
# balance                    0.085569  ...           0.017235     -0.037707
# duration                   0.006577  ...           0.011423     -0.000211
# campaign                  -0.127817  ...           0.003895     -0.004259
# pdays                      0.156656  ...          -0.014384      0.007112
# previous                   0.131636  ...          -0.002959     -0.011628
# y                          0.086606  ...           0.004024     -0.024128
# month_day_sin             -0.079836  ...          -0.024142      0.055700
# month_day_cos              1.000000  ...           0.034014     -0.035440
# marital_married           -0.031041  ...           0.002601     -0.015831
# marital_single             0.031393  ...           0.004955      0.007117
# default_yes               -0.022347  ...           0.006287     -0.005099
# housing_yes               -0.083300  ...          -0.029093      0.064518
# loan_yes                  -0.041005  ...          -0.011617      0.035714
# job_blue-collar           -0.099957  ...          -0.100004     -0.169224
# job_entrepreneur           0.019027  ...          -0.035474     -0.060028
# job_housemaid             -0.030608  ...          -0.032362     -0.054762
# job_management             0.052110  ...          -0.097112     -0.164330
# job_retired                0.031565  ...          -0.044166     -0.074737
# job_self-employed          0.034014  ...           1.000000     -0.061074
# job_services              -0.035440  ...          -0.061074      1.000000
# job_student                0.031467  ...          -0.027506     -0.046545
# job_technician             0.001917  ...          -0.084777     -0.143457
# job_unemployed             0.083783  ...          -0.032902     -0.055676
# education_management      -0.039627  ...          -0.066276      0.205981
# education_technician       0.086814  ...           0.105184     -0.176988
# contact_management         0.081383  ...          -0.007325     -0.008437
# poutcome_management       -0.259115  ...          -0.002052      0.015404
# poutcome_technician        0.051255  ...          -0.002360     -0.018493
#
#                       job_student  job_technician  job_unemployed  \
# id                       0.006958       -0.000349        0.000994
# age                     -0.195871       -0.065888        0.001172
# balance                  0.001307       -0.019928        0.009060
# duration                -0.009369       -0.006641        0.021198
# campaign                -0.021345        0.027572       -0.019626
# pdays                    0.025159       -0.007087       -0.006487
# previous                 0.019321        0.007965       -0.005428
# y                        0.081543       -0.015128        0.025624
# month_day_sin            0.006988       -0.083477        0.010224
# month_day_cos            0.031467        0.001917        0.083783
# marital_married         -0.157897       -0.055577       -0.010273
# marital_single           0.205371        0.056463        0.010165
# default_yes             -0.015587       -0.004022        0.006468
# housing_yes             -0.084025       -0.011912       -0.050520
# loan_yes                -0.057513        0.020882       -0.036710
# job_blue-collar         -0.076214       -0.234901       -0.091166
# job_entrepreneur        -0.027035       -0.083326       -0.032339
# job_housemaid           -0.024664       -0.076016       -0.029502
# job_management          -0.074010       -0.228108       -0.088530
# job_retired             -0.033660       -0.103743       -0.040263
# job_self-employed       -0.027506       -0.084777       -0.032902
# job_services            -0.046545       -0.143457       -0.055676
# job_student              1.000000       -0.064609       -0.025075
# job_technician          -0.064609        1.000000       -0.077285
# job_unemployed          -0.025075       -0.077285        1.000000
# education_management     0.038874        0.151764        0.001180
# education_technician    -0.006349       -0.035529       -0.022021
# contact_management       0.019737       -0.040316        0.012564
# poutcome_management     -0.030202       -0.003283       -0.009408
# poutcome_technician      0.059387       -0.002679        0.020866
#
#                       education_management  education_technician  \
# id                               -0.000704              0.001802
# age                              -0.056198             -0.087869
# balance                          -0.075578              0.097979
# duration                         -0.000293              0.003627
# campaign                         -0.017564              0.011621
# pdays                             0.019596             -0.010087
# previous                         -0.007584              0.022724
# y                                -0.027451              0.063568
# month_day_sin                     0.095131             -0.138438
# month_day_cos                    -0.039627              0.086814
# marital_married                  -0.012271             -0.098237
# marital_single                   -0.000787              0.114982
# default_yes                       0.013823             -0.012597
# housing_yes                       0.088261             -0.107769
# loan_yes                          0.055001             -0.051148
# job_blue-collar                   0.045523             -0.320432
# job_entrepreneur                 -0.051688              0.068860
# job_housemaid                    -0.071880             -0.057356
# job_management                   -0.420884              0.595919
# job_retired                      -0.027312             -0.068516
# job_self-employed                -0.066276              0.105184
# job_services                      0.205981             -0.176988
# job_student                       0.038874             -0.006349
# job_technician                    0.151764             -0.035529
# job_unemployed                    0.001180             -0.022021
# education_management              1.000000             -0.717926
# education_technician             -0.717926              1.000000
# contact_management               -0.012366             -0.042314
# poutcome_management               0.018476             -0.051308
# poutcome_technician              -0.020207              0.039370
#
#                       contact_management  poutcome_management  \
# id                              0.002645             0.003582
# age                             0.172744            -0.013460
# balance                         0.029963            -0.036253
# duration                       -0.017818            -0.046870
# campaign                        0.055935             0.068714
# pdays                           0.015162            -0.657569
# previous                        0.018798            -0.336882
# y                               0.015431            -0.204506
# month_day_sin                  -0.061249            -0.054899
# month_day_cos                   0.081383            -0.259115
# marital_married                 0.043342             0.007144
# marital_single                 -0.038560            -0.009024
# default_yes                    -0.015120            -0.014076
# housing_yes                    -0.081459            -0.060615
# loan_yes                       -0.011260            -0.023157
# job_blue-collar                -0.005645             0.041865
# job_entrepreneur               -0.003275            -0.008213
# job_housemaid                   0.041850             0.016418
# job_management                 -0.026620            -0.020231
# job_retired                     0.113778            -0.016142
# job_self-employed              -0.007325            -0.002052
# job_services                   -0.008437             0.015404
# job_student                     0.019737            -0.030202
# job_technician                 -0.040316            -0.003283
# job_unemployed                  0.012564            -0.009408
# education_management           -0.012366             0.018476
# education_technician           -0.042314            -0.051308
# contact_management              1.000000            -0.011346
# poutcome_management            -0.011346             1.000000
# poutcome_technician             0.031604            -0.467638
#
#                       poutcome_technician
# id                               0.010168
# age                              0.034344
# balance                          0.031568
# duration                         0.070765
# campaign                         0.042658
# pdays                            0.173681
# previous                         0.149258
# y                                0.385849
# month_day_sin                   -0.067777
# month_day_cos                    0.051255
# marital_married                 -0.039200
# marital_single                   0.035895
# default_yes                     -0.028473
# housing_yes                     -0.128150
# loan_yes                        -0.064847
# job_blue-collar                 -0.058139
# job_entrepreneur                -0.024295
# job_housemaid                   -0.004056
# job_management                   0.019292
# job_retired                      0.056670
# job_self-employed               -0.002360
# job_services                    -0.018493
# job_student                      0.059387
# job_technician                  -0.002679
# job_unemployed                   0.020866
# education_management            -0.020207
# education_technician             0.039370
# contact_management               0.031604
# poutcome_management             -0.467638
# poutcome_technician              1.000000
#
# [30 rows x 30 columns]

# %%
numeric_df = df_use.select_dtypes(include=['number'])
plt.figure(figsize=(12, 5))
sns.heatmap(numeric_df.corr())
plt.xticks(rotation=0)
plt.show()

# %%
df_use.describe()
# Out:
#                 age        balance      duration      campaign         pdays  \
# count  27128.000000   27128.000000  27128.000000  27128.000000  27128.000000
# mean      40.951010    1355.800870    260.711295      2.751769     40.528052
# std       10.608542    3003.305272    260.091727      3.126594    100.382462
# min       18.000000   -6847.000000      0.000000      1.000000     -1.000000
# 25%       33.000000      72.000000    104.000000      1.000000     -1.000000
# 50%       39.000000     449.000000    182.000000      2.000000     -1.000000
# 75%       48.000000    1428.000000    323.000000      3.000000     -1.000000
# max       95.000000  102127.000000   4918.000000     63.000000    871.000000
#
#            previous             y  month_day_sin  month_day_cos  \
# count  27128.000000  27128.000000   27128.000000   27128.000000
# mean       0.579733      0.117001       0.117734      -0.430013
# std        2.503653      0.321427       0.626244       0.639591
# min        0.000000      0.000000      -0.999991      -0.999963
# 25%        0.000000      0.000000      -0.552435      -0.873807
# 50%        0.000000      0.000000       0.393590      -0.708627
# 75%        0.000000      0.000000       0.680773      -0.317191
# max      275.000000      1.000000       0.999991       1.000000
#
#        marital_married  ...  job_self-employed  job_services   job_student  \
# count     27128.000000  ...       27128.000000  27128.000000  27128.000000
# mean          0.604947  ...           0.034835      0.093667      0.020532
# std           0.488871  ...           0.183365      0.291370      0.141815
# min           0.000000  ...           0.000000      0.000000      0.000000
# 25%           0.000000  ...           0.000000      0.000000      0.000000
# 50%           1.000000  ...           0.000000      0.000000      0.000000
# 75%           1.000000  ...           0.000000      0.000000      0.000000
# max           1.000000  ...           1.000000      1.000000      1.000000
#
#        job_technician  job_unemployed  education_management  \
# count    27128.000000    27128.000000          27128.000000
# mean         0.166065        0.029121              0.552308
# std          0.372145        0.168149              0.497266
# min          0.000000        0.000000              0.000000
# 25%          0.000000        0.000000              0.000000
# 50%          0.000000        0.000000              1.000000
# 75%          0.000000        0.000000              1.000000
# max          1.000000        1.000000              1.000000
#
#        education_technician  contact_management  poutcome_management  \
# count          27128.000000        27128.000000         27128.000000
# mean               0.294677            0.062224             0.830507
# std                0.455906            0.241566             0.375194
# min                0.000000            0.000000             0.000000
# 25%                0.000000            0.000000             1.000000
# 50%                0.000000            0.000000             1.000000
# 75%                1.000000            0.000000             1.000000
# max                1.000000            1.000000             1.000000
#
#        poutcome_technician
# count         27128.000000
# mean              0.042723
# std               0.202237
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               1.000000
#
# [8 rows x 29 columns]

# %%
#欠損値確認
df_use.isnull().sum()
# Out:
# id                      0
# age                     0
# balance                 0
# duration                0
# campaign                0
# pdays                   0
# previous                0
# y                       0
# month_day_sin           0
# month_day_cos           0
# marital_married         0
# marital_single          0
# default_yes             0
# housing_yes             0
# loan_yes                0
# job_blue-collar         0
# job_entrepreneur        0
# job_housemaid           0
# job_management          0
# job_retired             0
# job_self-employed       0
# job_services            0
# job_student             0
# job_technician          0
# job_unemployed          0
# education_management    0
# education_technician    0
# contact_management      0
# poutcome_management     0
# poutcome_technician     0
# dtype: int64

# %%
df_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27128 entries, 0 to 27127
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    27128 non-null  category
#  1   age                   27128 non-null  float64
#  2   balance               27128 non-null  float64
#  3   duration              27128 non-null  float64
#  4   campaign              27128 non-null  float64
#  5   pdays                 27128 non-null  float64
#  6   previous              27128 non-null  float64
#  7   y                     27128 non-null  float64
#  8   month_day_sin         27128 non-null  float64
#  9   month_day_cos         27128 non-null  float64
#  10  marital_married       27128 non-null  float64
#  11  marital_single        27128 non-null  float64
#  12  default_yes           27128 non-null  float64
#  13  housing_yes           27128 non-null  float64
#  14  loan_yes              27128 non-null  float64
#  15  job_blue-collar       27128 non-null  int64
#  16  job_entrepreneur      27128 non-null  int64
#  17  job_housemaid         27128 non-null  int64
#  18  job_management        27128 non-null  int64
#  19  job_retired           27128 non-null  int64
#  20  job_self-employed     27128 non-null  int64
#  21  job_services          27128 non-null  int64
#  22  job_student           27128 non-null  int64
#  23  job_technician        27128 non-null  int64
#  24  job_unemployed        27128 non-null  int64
#  25  education_management  27128 non-null  int64
#  26  education_technician  27128 non-null  int64
#  27  contact_management    27128 non-null  int64
#  28  poutcome_management   27128 non-null  int64
#  29  poutcome_technician   27128 non-null  int64
# dtypes: category(1), float64(14), int64(15)
# memory usage: 7.3 MB

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae


df_train,df_val =train_test_split(df_use,test_size=0.2,random_state=42)

col = "y"
train_y = df_train[col]
train_x = df_train.drop(col,axis=1)

val_y = df_val[col]
val_x =df_val.drop(col,axis=1)

trains = lgb.Dataset(train_x,train_y)
valids = lgb.Dataset(val_x,val_y)

params = {
    'objective': 'binary',      # 二値分類
    'metric': 'binary_logloss',       # 評価指標：（ロジスティック損失）
    'num_leaves': 31,               # 葉の数
    'learning_rate': 0.1,          # 学習率
    'feature_fraction': 1.0,        # 特徴量のサブサンプル率
    'bagging_fraction': 1.0,        # バギングのサブサンプル率
    'bagging_freq': 5,              # バギングの頻度
    'max_depth': -1,                # ツリーの最大深さ（制限なし）
    'min_data_in_leaf': 1        # 葉の最小データ数
    }

model = lgb.train(
    params,
    trains,
    valid_sets=valids,
    num_boost_round=1000,
    callbacks=[lgb.early_stopping(stopping_rounds=100)])
# Out:
# [LightGBM] [Info] Number of positive: 2565, number of negative: 19137
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020342 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1414
# [LightGBM] [Info] Number of data points in the train set: 21702, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.118192 -> initscore=-2.009665
# [LightGBM] [Info] Start training from score -2.009665
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [96]	valid_0's binary_logloss: 0.17847

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# モデルの予測
pred_y = model.predict(val_x, num_iteration=model.best_iteration)

# 平均二乗誤差（MSE）や平均絶対誤差（MAE）の計算
mse = mean_squared_error(val_y, pred_y)
mae = mean_absolute_error(val_y, pred_y)
print(f'MSE: {mse}, MAE: {mae}')
# Out:
# MSE: 0.0555366939736067, MAE: 0.10989541273078975

# %%
# 予測値から確率に変換する関数
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# モデルの予測値を確率に変換
pred_probs = sigmoid(pred_y)
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# ROC曲線とAUCの計算
fpr, tpr, thresholds = roc_curve(val_y, pred_probs)
auc = roc_auc_score(val_y, pred_probs)

# ROC曲線のプロット
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
plt.plot([0, 1], [0, 1], linestyle='--', color='r', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
print(auc)
# Out:
# 0.9440201012219653

# %%
#データ読み込み
df_test=pd.read_csv("/content/bank_test.csv")

# %%
df_test = data_pre(df_test)

# %%
predict = model.predict(df_test)
df_test["y"]=predict

# %%
df_ID=df_test["id"]
df_test["id"]=df_ID.astype(int)

# %%
df_test.to_csv("sample_submit.csv",columns=['id', 'y'],index = False,header = False)

# %%
lgb.plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix
# 予測（確率）
predict_prob = model.predict(val_x)
# 予測（クラス）
threshold = 0.5
predict_class = (predict_prob >= threshold).astype(int)
# 混同行列
conf_matrix = confusion_matrix(val_y, predict_class)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix
# 評価指標
accuracy = accuracy_score(val_y, predict_class)
precision = precision_score(val_y, predict_class)
recall = recall_score(val_y, predict_class)
f1 = f1_score(val_y, predict_class)
roc_auc = roc_auc_score(val_y, predict_prob)

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'ROC AUC: {roc_auc:.2f}')
# Out:
# Accuracy: 0.92
# Precision: 0.65
# Recall: 0.52
# F1 Score: 0.58
# ROC AUC: 0.94
